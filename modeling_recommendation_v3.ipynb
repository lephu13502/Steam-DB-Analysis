# %% [markdown]
# # Modeling (Recommendation System)
#
# ## Part 3: Hybrid Filtering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Self-made codes
from model.collaborative import CollaborativeFiltering
from model.contentbased import ContentBasedFiltering
from model.filter_funcs import *

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# This notebook will take advantage of the two model types of the previous notebooks.
#
# **Please notice that the code in python files were changed a little to unify both.**

# %% [markdown]
# ### Video game dataframe / `df_game` / `cleaned_steam_db_v2.csv` -> `game`

# %%
from gensim.models import Word2Vec, FastText

game = ContentBasedFiltering()
game.read_csv("archive/cleaned_steam_db_v2.csv")
game.get_genre_dict("json_folder/genre_dict_clean.json")
game.get_studio_dict("json_folder/studio_dict.json")
game.load_models(
    ["model/w2v_model.model", "model/ft_model.model"],
    [Word2Vec, FastText],
    ["model/w2v_vectors.json", "model/ft_vectors.json"]
)
game.df.head()
# Out:
#    type                                               name  steam_appid  \
# 0  demo                                      Pin Them Demo      1904630
# 1  game                        Al-Qadim: The Genie's Curse      1904640
# 2  game  Dungeons & Dragons - Stronghold: Kingdom Simul...      1904650
# 3  game                             Chapel 3-D: The Ascent      1904680
# 4  game                        VTuber Gallery : Anime Pose      1904690
#
#    required_age  is_free                    genres  platform_windows  \
# 0             0     True                        []              True
# 1             0    False                    [1, 3]              True
# 2             0    False                   [28, 2]              True
# 3             0    False                   [1, 23]              True
# 4             0     True  [51, 53, 55, 57, 59, 70]              True
#
#    platform_mac  platform_linux  release_year  ...   nsfw   film  developers  \
# 0         False           False        2023.0  ...  False  False         [0]
# 1         False           False        2022.0  ...  False  False         [1]
# 2         False           False        2022.0  ...  False  False         [3]
# 3         False           False           NaN  ...  False  False         [4]
# 4         False           False        2022.0  ...  False  False         [6]
#
#    publishers                                        description  \
# 0         [0]                                                NaN
# 1         [2]  Experience the mysterious Al-Qadim game world ...
# 2         [2]  Run your own kingdom in the legendary Dungeons...
# 3         [5]   Chapel 3-D: The Ascent is a break-neck, viole...
# 4         [6]  VTuber Gallery is #1 anime pose app that allow...
#
#    release_distance_value  initial_price_usd  final_price_usd  memory_gb  \
# 0                       2              0.000            0.000        NaN
# 1                       2              3.204            3.204        0.5
# 2                       2              3.204            3.204        0.5
# 3                       0              0.000            0.000        1.0
# 4                       2              0.000            0.000        8.0
#
#    storage_gb
# 0         NaN
# 1         2.0
# 2         2.0
# 3         0.0
# 4         0.0
#
# [5 rows x 42 columns]

# %% [markdown]
# ### The bridge between `df_game` and `df_review` / `df_bridge` / `cleaned_bridge.csv` -> `bridge`

# %%
bridge = pd.read_csv("archive/cleaned_bridge.csv", index_col=[0])
bridge.head()
# Out:
#      appid  num_reviews  review_score review_score_desc  total_positive  \
# 0  1020470            2             6   Mostly Positive             360
# 1  1018050            0             0   No user reviews               0
# 2  1018060            0             0   No user reviews               0
# 3  1018080            3             0    3 user reviews               2
# 4  1018090            7             0    7 user reviews               1
#
#    total_negative  total_reviews
# 0             106            466
# 1               0              0
# 2               0              0
# 3               1              3
# 4               6              7

# %% [markdown]
# ### The review dataframe / `df_review` / `cleaned_reviews_v2.csv` -> `review`

# %%
from surprise import KNNBasic, KNNWithMeans, SlopeOne

review = CollaborativeFiltering()
review.read_csv("archive/cleaned_reviews_v2.csv")
review.fit_models([
    KNNBasic(sim_options={ "user_based": True }),
	KNNWithMeans(sim_options={ "user_based": False }),
    SlopeOne()
])
review.df.head()
# Out:
#    recommendationid                                             review  \
# 0          55936147  A fun and quirky stealth-based problem solving...
# 1          55989797  Loved the art style, and the game ran very smo...
# 2          64251252  the game crashed four times for one hour.... i...
# 3          49140086  While I cannot recommend this Unity asset reli...
# 4          49137406  Is extremely unoptimized and has laggy framera...
#
#     timestamp_created   timestamp_updated  voted_up  votes_up  votes_funny  \
# 0 2019-10-31 02:33:41 2019-10-31 02:33:41      True         2            0
# 1 2019-10-31 11:57:40 2019-10-31 11:57:40      True         1            0
# 2 2020-02-28 16:21:55 2020-02-28 16:26:49     False         0            0
# 3 2019-02-21 15:52:16 2019-02-21 15:52:16     False        16            0
# 4 2019-02-21 13:10:21 2019-02-21 13:10:21     False        11            0
#
#    weighted_vote_score  comment_count  steam_purchase  received_for_free  \
# 0             0.554140              0            True              False
# 1             0.523810              0            True              False
# 2             0.000000              0            True              False
# 3             0.624971              0            True              False
# 4             0.527824              0            True              False
#
#    written_during_early_access    appid            steamid  num_games_owned  \
# 0                        False  1018080  76561198051821837                0
# 1                        False  1018080  76561197993790846              657
# 2                        False  1018080  76561198095855343             1254
# 3                        False  1018090  76561198053422627             2384
# 4                        False  1018090  76561198019816374             1351
#
#    num_reviews  playtime_forever  playtime_last_two_weeks  playtime_at_review  \
# 0           12                41                        0                41.0
# 1            8                17                        0                15.0
# 2           24                76                        0                76.0
# 3         1225                56                        0                56.0
# 4         1674                10                        0                10.0
#
#           last_played
# 0 2019-10-31 00:52:26
# 1 2019-11-03 09:37:50
# 2 2020-02-28 16:16:07
# 3 2019-02-23 20:59:13
# 4 2019-02-21 11:27:35

# %%
game_full = pd.merge(game.df, bridge, how="left", left_on="steam_appid", right_on="appid")
game_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95033 entries, 0 to 95032
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   type                    95033 non-null  object
#  1   name                    95033 non-null  object
#  2   steam_appid             95033 non-null  int64
#  3   required_age            95033 non-null  int64
#  4   is_free                 95033 non-null  bool
#  5   genres                  95033 non-null  object
#  6   platform_windows        95033 non-null  bool
#  7   platform_mac            95033 non-null  bool
#  8   platform_linux          95033 non-null  bool
#  9   release_year            84290 non-null  float64
#  10  release_quarter         82811 non-null  float64
#  11  coming_soon             95033 non-null  bool
#  12  package_number          95033 non-null  int64
#  13  discount_percent        95033 non-null  float64
#  14  developers_amount       95033 non-null  int64
#  15  publishers_amount       95033 non-null  int64
#  16  single                  95033 non-null  bool
#  17  multi                   95033 non-null  bool
#  18  support_vr              95033 non-null  bool
#  19  support_controller      95033 non-null  bool
#  20  lang_en                 95033 non-null  bool
#  21  lang_fr                 95033 non-null  bool
#  22  lang_de                 95033 non-null  bool
#  23  lang_es                 95033 non-null  bool
#  24  lang_po                 95033 non-null  bool
#  25  lang_zh                 95033 non-null  bool
#  26  lang_ja                 95033 non-null  bool
#  27  lang_ko                 95033 non-null  bool
#  28  lang_it                 95033 non-null  bool
#  29  lang_ru                 95033 non-null  bool
#  30  lang_ar                 95033 non-null  bool
#  31  tool                    95033 non-null  bool
#  32  nsfw                    95033 non-null  bool
#  33  film                    95033 non-null  bool
#  34  developers              95033 non-null  object
#  35  publishers              95033 non-null  object
#  36  description             88076 non-null  object
#  37  release_distance_value  95033 non-null  int64
#  38  initial_price_usd       95033 non-null  float64
#  39  final_price_usd         95033 non-null  float64
#  40  memory_gb               70971 non-null  float64
#  41  storage_gb              70170 non-null  float64
#  42  appid                   94026 non-null  float64
#  43  num_reviews             94026 non-null  float64
#  44  review_score            94026 non-null  float64
#  45  review_score_desc       94026 non-null  object
#  46  total_positive          94026 non-null  float64
#  47  total_negative          94026 non-null  float64
#  48  total_reviews           94026 non-null  float64
# dtypes: bool(23), float64(13), int64(6), object(7)
# memory usage: 20.9+ MB

# %%
output_features = ["type", "name", "steam_appid", "required_age", "genres",  "release_year",
   "final_price_usd", "memory_gb", "storage_gb", "review_score", "review_score_desc", "total_reviews"]

# %% [markdown]
# ___
#
# ## User treatment
#
# Imagine we are a service of the Steam and Valve, and there are several types of users.
#
# |Type                                |Popular|On sale |Content-based|Collaborative|
# |------------------------------------|-------|--------|-------------|-------------|
# |new users                           |✅✅  |✅      |✅✅        |             |
# |old users                           |✅     |✅✅   |✅           |✅✅        |
# |users with conditions (ages, etc.)  |✅     |✅      |✅✅        |✅✅        |
# |users loving free/on sale games     |✅     |✅✅   |✅          |✅           |
#
# Where:
# - []: Unable to use the model.
# - \[✅\]: Usable.
# - \[✅✅\]: Very relevant.

# %% [markdown]
# ___
#
# ### Popular apps
#
# Popular apps have high number of ratings. They can be positive or negative, but let the users choose their games.
#
# **Pros**:
# - Extremely easy to recommend.
# - Many players will try to own them due to their popularity and their great fandom.
#
# **Cons**:
# - Some games are really heavy, or having negative reviews. Some of these are not novel comparing to the new released ones.
#
# **Where to recommend**:
# - **Top 1**. On the top of the UI, so that everyone will see it at the beginning.

# %%
def filter_by_number_of_reviews(df, threshold, top_n=10, shuffle=True,
                                filter_func_list: list = [], ignored_appids: list = []):
    
    recommendation_table = df[df["total_reviews"] > threshold]

    # If shuffle = true: shuffle the results to avoid not recommend less popular ones
    # Otherwise: recommend the top most reviews apps
    if shuffle:
        recommendation_table.sample(frac=1)
    else:
        recommendation_table.sort_values(by=["total_reviews", "review_score"], ascending=False)

    # Apply filter
    if len(filter_func_list) > 0:
        for func in filter_func_list:
            recommendation_table = func(recommendation_table)

    recommendation_table = recommendation_table[~recommendation_table["appid"].isin(ignored_appids)]

    return recommendation_table[:top_n]

# %%
for pin in [0, 1, 25, 50, 75, 99, 100]:
    print("percentile = {}: {}".format(pin / 100, np.percentile(game_full["total_reviews"].dropna(), pin)))
# Out:
# percentile = 0.0: 0.0
# percentile = 0.01: 0.0
# percentile = 0.25: 0.0
# percentile = 0.5: 0.0
# percentile = 0.75: 8.0
# percentile = 0.99: 3044.5
# percentile = 1.0: 1222889.0

# %%
# It seems not that many games have more than 3000 reviews
# Let's obtain percentile 0.99 as threshold
filter_by_number_of_reviews(
    game_full,
    np.percentile(game_full["total_reviews"].dropna(), 99),
    top_n=15,
    ignored_appids=[2138330]  # Cyberpunk 2077: Phantom Liberty	
)[output_features]
# Out:
#        type                                  name  steam_appid  required_age  \
# 53     game                 Football Manager 2023      1904540             0
# 1059   game                        Lethal Company      1966720             0
# 1073   game                  20 Minutes Till Dawn      1966900             0
# 1902   game        Call of Duty®: Modern Warfare®      2000950            18
# 1990   game         Placid Plastic Duck Simulator      1999360             0
# 3267   game                         Madden NFL 24      2140330             0
# 4220   game               Return to Monkey Island      2060130             0
# 9444   game          Tom Clancy’s The Division® 2      2221490            18
# 9923   game             Assassin's Creed Valhalla      2208920            17
# 11736  game                            Thronefall      2239150             0
# 12157  game                           Potionomics      1874490             0
# 12385  game                          WILD HEARTS™      1938010            13
# 12744  game  Tom Clancy's Ghost Recon® Breakpoint      2231380            18
# 13965  game                        Death Must Die      2334730             0
# 22076  game                          Demonologist      1929610             0
#
#                   genres  release_year  final_price_usd  memory_gb  \
# 53              [28, 18]        2022.0         0.000000        4.0
# 1059     [1, 25, 23, 70]        2023.0         8.173000        NaN
# 1073   [1, 25, 4, 23, 2]        2023.0         2.943675        1.0
# 1902                 [1]        2023.0         0.000000        8.0
# 1990             [4, 28]        2022.0         1.201500        4.0
# 3267         [28, 18, 2]        2023.0         0.000000       10.0
# 4220             [25, 4]        2022.0        12.856050        8.0
# 9444          [1, 25, 3]        2023.0        19.824750        8.0
# 9923          [1, 25, 3]        2022.0        59.990000        8.0
# 11736     [1, 23, 2, 70]        2023.0         5.687100        4.0
# 12157     [23, 3, 28, 2]        2022.0         8.811000        8.0
# 12385            [1, 25]        2023.0        66.443847       12.0
# 12744            [1, 25]        2023.0        39.649500        8.0
# 13965  [1, 4, 23, 3, 70]        2023.0         4.085100        4.0
# 22076        [1, 25, 23]        2023.0         9.491850        NaN
#
#        storage_gb  review_score        review_score_desc  total_reviews
# 53           7.00           8.0            Very Positive         5374.0
# 1059         1.00           9.0  Overwhelmingly Positive       208193.0
# 1073         0.00           8.0            Very Positive        11168.0
# 1902        60.00           8.0            Very Positive         4547.0
# 1990         0.50           9.0  Overwhelmingly Positive         7818.0
# 3267        50.00           5.0                    Mixed         5354.0
# 4220         4.00           8.0            Very Positive         4359.0
# 9444        60.00           6.0          Mostly Positive         6641.0
# 9923        60.00           5.0                    Mixed         7117.0
# 11736        0.25           9.0  Overwhelmingly Positive         5389.0
# 12157        7.00           8.0            Very Positive         4011.0
# 12385       60.00           5.0                    Mixed         3479.0
# 12744       60.00           6.0          Mostly Positive         7214.0
# 13965        3.00           8.0            Very Positive         7995.0
# 22076       20.00           8.0            Very Positive         7502.0

# %% [markdown]
# ___
#
# ### On sales apps
#
# This will include free games and on sale ones (with discount larger than 0).
#
# **Pros**:
# - Extremely easy to recommend.
# - More people will look for other unknown games.
#
# **Cons**:
# - Some paid games don't want to be on sale, and they can be ignored.
#
# **Where to recommend**:
# - **Top 2**. Right after the list of popular apps/games, so that everyone will consider buying them.

# %%
def filter_by_on_sale(df, top_n=10, shuffle=True,
                      filter_func_list: list = [], ignored_appids: list = []):
    
    recommendation_table = df[(df["discount_percent"] > 0) | (df["final_price_usd"] == 0)]

    if shuffle:
        recommendation_table.sample(frac=1)
    else:
        recommendation_table.sort_values(by=["total_reviews", "review_score"], ascending=False)

    # Apply filter
    if len(filter_func_list) > 0:
        for func in filter_func_list:
            recommendation_table = func(recommendation_table)

    recommendation_table = recommendation_table[~recommendation_table["appid"].isin(ignored_appids)]

    return recommendation_table[:top_n]

# %%
# It seems not that many games have more than 3000 reviews
# Let's obtain percentile 0.99 as threshold
filter_by_on_sale(
    game_full,
    top_n=15,
    filter_func_list=[
        filter_games_only,
        filter_positive_apps,
        lambda x: x[x["total_reviews"] > 300]
    ],
    ignored_appids=[2138330]  # Cyberpunk 2077: Phantom Liberty	
)[[*output_features, "initial_price_usd", "discount_percent"]]
# Out:
#       type                                               name  steam_appid  \
# 53    game                              Football Manager 2023      1904540
# 114   game                                   Killer Frequency      1903620
# 630   game                                             Jusant      1977170
# 896   game                               OCTOPATH TRAVELER II      1971650
# 920   game                                 Warlord: Britannia      1970980
# 1042  game                     Ghost Trick: Phantom Detective      1967430
# 1048  game                                          Railbound      1967510
# 1765  game                                     Void Scrappers      2005210
# 1902  game                     Call of Duty®: Modern Warfare®      2000950
# 1952  game  Atelier Ryza 3: Alchemist of the End & the Sec...      1999770
# 3606  game  METAL GEAR SOLID 2: Sons of Liberty - Master C...      2131640
# 4278  game                                         Quasimorph      2059170
# 5419  game                         Hand Simulator: Rendezvous      2158730
# 5918  game                            The Backrooms: Survival      1889640
# 5943  game                                              Birth      1889040
#
#       required_age               genres  release_year  final_price_usd  \
# 53               0             [28, 18]        2022.0         0.000000
# 114              0         [25, 23, 28]        2023.0        10.012500
# 630              0          [1, 25, 23]        2023.0        15.399225
# 896              0                  [3]        2023.0         0.000000
# 920              0       [1, 25, 23, 2]        2022.0         5.647050
# 1042             0              [1, 25]        2023.0        18.282825
# 1048             0              [4, 23]        2022.0         4.826025
# 1765             0                  [1]        2022.0         1.421775
# 1902            18                  [1]        2023.0         0.000000
# 1952             0       [25, 4, 3, 28]        2023.0         0.000000
# 3606            18                  [1]        2023.0         0.000000
# 4278             0   [23, 3, 28, 2, 70]        2023.0         8.330400
# 5419             0             [23, 28]        2022.0         0.600750
# 5918             0  [1, 25, 23, 29, 28]        2023.0         3.404250
# 5943             0             [25, 23]        2023.0         3.904875
#
#       memory_gb  storage_gb  review_score        review_score_desc  \
# 53          4.0        7.00           8.0            Very Positive
# 114         4.0        2.00           8.0            Very Positive
# 630         8.0       15.00           8.0            Very Positive
# 896         8.0       10.00           9.0  Overwhelmingly Positive
# 920         8.0        5.00           8.0            Very Positive
# 1042        8.0        7.00           9.0  Overwhelmingly Positive
# 1048        4.0        0.25           8.0            Very Positive
# 1765        2.0        0.25           8.0            Very Positive
# 1902        8.0       60.00           8.0            Very Positive
# 1952        8.0       50.00           8.0            Very Positive
# 3606        8.0       17.00           6.0          Mostly Positive
# 4278        2.0        0.25           8.0            Very Positive
# 5419        2.0        8.00           8.0            Very Positive
# 5918        4.0        1.00           8.0            Very Positive
# 5943        NaN        2.00           9.0  Overwhelmingly Positive
#
#       total_reviews  initial_price_usd  discount_percent
# 53           5374.0           0.000000               0.0
# 114          1609.0          20.025000              50.0
# 630          1119.0          20.525625              25.0
# 896          2879.0           0.000000               0.0
# 920          1188.0           7.529400              25.0
# 1042         1136.0          27.714600              34.0
# 1048          452.0           7.209000              33.0
# 1765          325.0           2.362950              40.0
# 1902         4547.0           0.000000               0.0
# 1952          345.0           0.000000               0.0
# 3606          581.0           0.000000               0.0
# 4278         1095.0          10.413000              20.0
# 5419          477.0           1.201500              50.0
# 5918          472.0           5.687100              40.0
# 5943         1236.0           5.206500              25.0

# %% [markdown]
# ___
#
# ### Content-based Filtering
#
# Based on all the existing features, we apply NLP to the model to obtain the vectors of each item. After that, we use metrics to figure the similar items out.
#
# **Pros**:
# - All of the games can be possibly included.
# - Take advantage of categories and description features.
#
# **Cons**:
# - Complicated model that requires time and storage.
# - Sometimes the recommended items can be absurd.
# - Pretty slow for recommending if not optimised properly (since the model has to check through all of the items to find the best among them).
#
# **Where to recommend**:
# - **Top 4**. At the end of the UI. This will recommend the games that are similar to the ones users have played before.

# %%
game.get_top_10(
    name="Goat Simulator",
    vectorised_id=1,
    df_bridge=df_bridge,
    filter_func_list=[
        filter_games_only,
        filter_affordable_apps,
        filter_restricted_age,
        lambda x: filter_light_storage_games(x, threshold=10, including_null=True)
    ],
    ignored_appids=[850190] # Goat Simulator 3
)[["type", "name", "steam_appid", "required_age", "genres",  "release_year",
   "final_price_usd", "memory_gb", "storage_gb", "review_score", "review_score_desc", "total_reviews"]]
# Out:
#     type                                     name  steam_appid  required_age  \
# 0   game                            Bloody trains      1185000             0
# 1   game                                 Sand:box      2179380             0
# 2   game                         XiJiang Shipyard      2690180             0
# 3   game    Boba Simulator : Idle Shop Management      1847510             0
# 5   game                    Pro Gymnast Simulator      1214520             0
# 6   game                               Townscaper      1291340             0
# 7   game                             ELON on MARS      1120920             0
# 8   game                        Sexy Nurse Puzzle      2325640             0
# 9   game                                Economica      1215380             0
# 10  game  Virtual Aquarium - Overlay Desktop Game      1791120             0
#
#                 genres  release_year  final_price_usd  memory_gb  storage_gb  \
# 0          [1, 23, 28]        2019.0         0.740925        2.0        1.00
# 1          [4, 23, 28]        2023.0         2.362950        1.0        0.00
# 2             [23, 28]        2024.0         8.210250        8.0        8.00
# 3   [4, 23, 28, 2, 70]        2022.0         2.362950        4.0        0.25
# 5      [1, 23, 28, 18]        2020.0        14.990000        1.0        1.00
# 6          [4, 23, 28]        2021.0         3.504375        4.0        1.00
# 7      [23, 9, 28, 18]        2019.0         0.600750        1.0        0.00
# 8          [4, 23, 28]        2023.0         1.201500        0.0        0.25
# 9          [23, 28, 2]        2020.0         4.005000        2.0        0.00
# 10         [4, 37, 28]        2022.0         0.000000        2.0        0.50
#
#     review_score        review_score_desc  total_reviews
# 0            0.0           5 user reviews            5.0
# 1            8.0            Very Positive          188.0
# 2            0.0          No user reviews            0.0
# 3            8.0            Very Positive          110.0
# 5            7.0                 Positive           42.0
# 6            9.0  Overwhelmingly Positive         9741.0
# 7            0.0           8 user reviews            8.0
# 8            7.0                 Positive           10.0
# 9            0.0           1 user reviews            1.0
# 10           0.0          No user reviews            0.0

# %% [markdown]
# ___
#
# ### Collaborative Filtering
#
# Based on the rating, we can extract the relevant games for each users.
#
# **Pros**:
# - Reliable, especially when users have high number of ratings for each game.
# - Pretty fast for recommending.
#
# **Cons**:
# - Require users to rate the games. The number should be at least three.
# - The data's size is the problem for performance (In fact, Steam has 120 million users and 73 thousands apps (not including DLC)).
# - Still pretty complicated when compiling.
#
# **Where to recommend**:
# - **Top 3**. It's much less absurd than Content-based Filtering model.
# - However, if the user is new without proper ratings, this model will ignore recommending.

# %%
review.get_top_10(
    user=76561198104631037,
    model_id_list=[2],
    df_game=game.df[["type", "name", "steam_appid", "required_age", "genres",  "release_year", "final_price_usd", "memory_gb", "storage_gb"]],
    df_bridge=bridge[["appid", "review_score", "review_score_desc", "total_reviews"]],
    filter_func_list=[
        filter_games_only,
        filter_affordable_apps,
        lambda x: filter_light_storage_games(x, threshold=10, including_null=True)
    ])
# Out:
#     appid likely_to_like  type  \
# 14     70            YES  game
# 20   2280            YES  game
# 27   3540            YES  game
# 31   4570            YES  game
# 32   4580            YES  game
# 33   4700            YES  game
# 46   8930            YES  game
# 51   9450            YES  game
# 76  22320            YES  game
# 77  22380            YES  game
#
#                                                  name  steam_appid  \
# 14                                          Half-Life           70
# 20                                        DOOM (1993)         2280
# 27                                     Peggle™ Nights         3540
# 31  Warhammer® 40,000: Dawn of War® - Game of the ...         4570
# 32     Warhammer® 40,000: Dawn of War® - Dark Crusade         4580
# 33        Total War: MEDIEVAL II – Definitive Edition         4700
# 46                        Sid Meier's Civilization® V         8930
# 51        Warhammer® 40,000: Dawn of War® - Soulstorm         9450
# 76  The Elder Scrolls III: Morrowind® Game of the ...        22320
# 77                                 Fallout: New Vegas        22380
#
#     required_age  genres  release_year  final_price_usd  memory_gb  \
# 14             0     [1]        1998.0         4.806000        NaN
# 20             0     [1]        2007.0         4.505625        NaN
# 27             0     [4]        2008.0         2.803500        NaN
# 31            16     [2]        2007.0         6.007500        NaN
# 32            16     [2]        2007.0         6.007500        NaN
# 33             0     [2]        2006.0        14.698350        NaN
# 46             0     [2]        2010.0        20.425500        2.0
# 51            16     [2]        2008.0         6.007500        0.5
# 76             0     [3]        2009.0        13.516875        0.0
# 77            17  [1, 3]        2010.0         9.011250        2.0
#
#     storage_gb  review_score        review_score_desc  total_reviews
# 14         NaN             9  Overwhelmingly Positive          45410
# 20         NaN             9  Overwhelmingly Positive          10333
# 27         NaN             9  Overwhelmingly Positive           1341
# 31         NaN             9  Overwhelmingly Positive           4383
# 32         NaN             9  Overwhelmingly Positive           4044
# 33         NaN             9  Overwhelmingly Positive          14140
# 46         NaN             9  Overwhelmingly Positive          72884
# 51         NaN             9  Overwhelmingly Positive           6736
# 76         NaN             9  Overwhelmingly Positive          14705
# 77         NaN             9  Overwhelmingly Positive         124455

# %% [markdown]
# ___
#
# ## Conclusion
#
# Taking advantage of all the models to recommend items to users is essential to keep users. Especially video games store, where the people find the relevant games for entertainment and stress reduction.
#
# There are still some recommendation ideas such as based on the subscribed developers or publishers, or improve the **Popular games** by applying the users' taste to it.
